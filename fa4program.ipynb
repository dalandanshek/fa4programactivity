# %% [markdown]
# <a href="https://colab.research.google.com/github/dalandanshek/fa4programactivity/blob/main/fa4program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for num in range(1, 21):
  if num % 2 == 0:
    continue
  print(num)

# %%
def check_password(correct_password):
    password_input = ''
    while password_input != correct_password:
        password_input = input("Enter password:")
        if password_input != correct_password:
            print("Incorrect. Try again.")
    print("Access granted.")

check_password("P1S@Y")

# %%
for num in range(1, 11):
    if num == 4:
        continue
    if num == 6:
        pass
    if num == 8:
        break
    print(num)
